# %%
import logging
import time
import pandas as pd
from datetime import datetime, timedelta
from concurrent.futures import ThreadPoolExecutor, as_completed
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.common.exceptions import TimeoutException, NoSuchElementException
import re

logging.basicConfig(
    level=logging.INFO,
    format="%(asctime)s - %(levelname)s - %(message)s",
    handlers=[
        logging.FileHandler("kayak030325.log"),  
        logging.StreamHandler() 
    ]
)

OUTPUT_CSV_PATH = "flight_prices_kayak03032511.csv"
CURRENCY = "USD"
SNAPSHOTS = 1
TTT_RANGE = range(1, 31)
LOS_RANGE = range(1, 6)
ROUTES = [
    # ("PAR", "LON"),
    # ("LON", "PAR"),
    ("ROM", "PAR"),
    ("PAR", "ROM"),
    # ("LON", "ROM"),
    # ("ROM", "LON")
]
MAX_SEARCHES = 10000
MAX_WORKERS = 15

def init_driver():
    options = webdriver.ChromeOptions()
    # options.add_argument("--headless")
    options.add_argument("--disable-gpu")
    options.add_argument("--no-sandbox")
    options.add_argument("--disable-dev-shm-usage")
    driver = webdriver.Chrome(options=options)
    return driver

def convert_duration_to_hours(duration):
    total_minutes = 0
    parts = duration.replace(' ', '')
    
    if 'h' in parts:
        hours_parts = parts.split('h')
        if hours_parts[0]:
            total_minutes += int(hours_parts[0]) * 60
        parts = hours_parts[1] 
    
    if 'm' in parts:
        minutes_parts = parts.split('m')
        if minutes_parts[0]:
            total_minutes += int(minutes_parts[0])
    
    return round(total_minutes / 60, 2)

def generate_dates(ttt, los, snapshot_date):
    departure_date = snapshot_date + timedelta(days=ttt)
    return_date = departure_date + timedelta(days=los)
    return departure_date.strftime("%Y-%m-%d"), return_date.strftime("%Y-%m-%d")

def scrape_flight_data(origin, destination, ttt, los, snapshot_date):
    driver = init_driver()
    flight_data = []

    try:
        departure_date, return_date = generate_dates(ttt, los, snapshot_date)
        search_url = (
            f"https://www.kayak.com/flights/{origin}-{destination}/{departure_date}/{return_date}"
        )

        logging.info(f"Fetching flights: {origin} → {destination} ({departure_date} - {return_date})")
        driver.get(search_url)
        time.sleep(5) 

        try:
            view_more_button = driver.find_element(By.XPATH, "//div[contains(@class, 'show-more-button')]")
            view_more_button.click()
            time.sleep(3)
        except NoSuchElementException:
            logging.warning(f"No 'View more flights' button found for {origin} → {destination}")


        flights = driver.find_elements(By.CSS_SELECTOR, "div.yuAt.yuAt-pres-rounded.yuAt-mod-box-shadow.yuAt-mod-responsive-margins")

        for _ in range(10):
            driver.find_element(By.TAG_NAME, "body").send_keys(Keys.PAGE_DOWN)
            time.sleep(1)

        for flight in flights[:100]:
            try:
                airline = flight.find_element(By.CSS_SELECTOR, "div.c_cgF.c_cgF-mod-variant-default").text
                price = flight.find_element(By.CSS_SELECTOR, "div.f8F1-price-text").text
                duration_str = driver.find_element(By.CSS_SELECTOR, "div.xdW8").text
                duration_hours = convert_duration_to_hours(duration_str)
                stops = flight.find_element(By.CSS_SELECTOR, "span.JWEO-stops-text").text.strip()
                airports = flight.find_element(By.CSS_SELECTOR, "div.EFvI").text
                departure_airport, arrival_airport = airports.split("-")
                time_element = flight.find_element(By.CSS_SELECTOR, "div.vmXl.vmXl-mod-variant-large")
                times = time_element.find_elements(By.TAG_NAME, "span")
                departure_time = times[0].text
                arrival_time = times[-1].text
                layover_element = driver.find_element(By.CSS_SELECTOR, ".c_cgF span span")
                layover_text = layover_element.get_attribute("title") 
                match = re.search(r"\d+h \d+m layover", layover_text)
                layover_duration = match.group(0) if match else "0"
                layover_duration_in_hours = convert_duration_to_hours(layover_duration)

                flight_data.append({
                    "Website": "Kayak",
                    "Snapshot date": snapshot_date.strftime("%Y-%m-%d"),
                    "Airline": airline,
                    "Price": price,
                    "TTT": ttt,
                    "LOS": los,
                    "Origin": origin,
                    "Destination": destination,
                    "Departure date": departure_date,
                    "Departure Airport": departure_airport,
                    "Departure Time": departure_time,
                    "Layover": layover_duration_in_hours,
                    "Stops": stops,
                    "Return date": return_date,
                    "Arrival Airport": arrival_airport,
                    "Arrival Time": arrival_time,
                    "Duration": duration_hours,
                })
            except Exception as e:
                logging.error(f"Error extracting flight data for {origin} → {destination}: {e}")

    except TimeoutException:
        logging.error(f"Timeout loading page for {origin} → {destination}")

    except Exception as e:
        logging.error(f"Unexpected error while scraping {origin} → {destination}: {e}")

    finally:
        driver.quit()

    logging.info(f"Completed: {origin} → {destination} (TTT: {ttt}, LOS: {los}), Found {len(flight_data)} flights.")
    return flight_data

def main():
    """Main function to coordinate web scraping."""
    data = []
    search_count = 0

    snapshot_dates = [datetime.now() + timedelta(days=7 * i) for i in range(SNAPSHOTS)]
    with ThreadPoolExecutor(max_workers=MAX_WORKERS) as executor:
        futures = []
        for snapshot_date in snapshot_dates:
            for origin, destination in ROUTES:
                for ttt in TTT_RANGE:
                    for los in LOS_RANGE:
                        if search_count >= MAX_SEARCHES:
                            break
                        futures.append(
                            executor.submit(scrape_flight_data, origin, destination, ttt, los, snapshot_date)
                        )
                        search_count += 1
                        logging.info(f"Scheduled search {search_count} of {MAX_SEARCHES}")

                    if search_count >= MAX_SEARCHES:
                        break
                if search_count >= MAX_SEARCHES:
                    break
            if search_count >= MAX_SEARCHES:
                break

        for future in as_completed(futures):
            try:
                flight_data = future.result()
                data.extend(flight_data)
            except Exception as e:
                logging.error(f"Error in future execution: {e}")

    df = pd.DataFrame(data)
    df.to_csv(OUTPUT_CSV_PATH, index=False)
    logging.info(f"Data successfully saved to {OUTPUT_CSV_PATH}")

if __name__ == "__main__":
    main()
# Out:
# 2025-03-04 18:12:48,826 - INFO - Scheduled search 1 of 10000
# 2025-03-04 18:12:48,827 - INFO - Scheduled search 2 of 10000
# 2025-03-04 18:12:48,832 - INFO - Scheduled search 3 of 10000
# 2025-03-04 18:12:48,835 - INFO - Scheduled search 4 of 10000
# 2025-03-04 18:12:48,840 - INFO - Scheduled search 5 of 10000
# 2025-03-04 18:12:48,845 - INFO - Scheduled search 6 of 10000
# 2025-03-04 18:12:48,851 - INFO - Scheduled search 7 of 10000
# 2025-03-04 18:12:48,856 - INFO - Scheduled search 8 of 10000
# 2025-03-04 18:12:48,863 - INFO - Scheduled search 9 of 10000
# 2025-03-04 18:12:48,867 - INFO - Scheduled search 10 of 10000
# 2025-03-04 18:12:48,870 - INFO - Scheduled search 11 of 10000
# 2025-03-04 18:12:48,875 - INFO - Scheduled search 12 of 10000
# 2025-03-04 18:12:48,891 - INFO - Scheduled search 13 of 10000
# 2025-03-04 18:12:48,922 - INFO - Scheduled search 14 of 10000
# 2025-03-04 18:12:48,935 - INFO - Scheduled search 15 of 10000
# 2025-03-04 18:12:48,955 - INFO - Scheduled search 16 of 10000
# 2025-03-04 18:12:48,969 - INFO - Scheduled search 17 of 10000
# 2025-03-04 18:12:49,002 - INFO - Scheduled search 18 of 10000
# 2025-03-04 18:12:49,008 - INFO - Scheduled search 19 of 10000
# 2025-03-04 18:12:49,040 - INFO - Scheduled search 20 of 10000
# 2025-03-04 18:12:49,044 - INFO - Scheduled search 21 of 10000
# 2025-03-04 18:12:49,048 - INFO - Scheduled search 22 of 10000
# 2025-03-04 18:12:49,052 - INFO - Scheduled search 23 of 10000
# 2025-03-04 18:12:49,054 - INFO - Scheduled search 24 of 10000
# 2025-03-04 18:12:49,057 - INFO - Scheduled search 25 of 10000
# 2025-03-04 18:12:49,059 - INFO - Scheduled search 26 of 10000
# 2025-03-04 18:12:49,060 - INFO - Scheduled search 27 of 10000
# 2025-03-04 18:12:49,060 - INFO - Scheduled search 28 of 10000
# 2025-03-04 18:12:49,061 - INFO - Scheduled search 29 of 10000
# 2025-03-04 18:12:49,064 - INFO - Scheduled search 30 of 10000
# 2025-03-04 18:12:49,072 - INFO - Scheduled search 31 of 10000
# 2025-03-04 18:12:49,076 - INFO - Scheduled search 32 of 10000
# 2025-03-04 18:12:49,077 - INFO - Scheduled search 33 of 10000
# 2025-03-04 18:12:49,079 - INFO - Scheduled search 34 of 10000
# 2025-03-04 18:12:49,082 - INFO - Scheduled search 35 of 10000
# 2025-03-04 18:12:49,083 - INFO - Scheduled search 36 of 10000
# 2025-03-04 18:12:49,084 - INFO - Scheduled search 37 of 10000
# 2025-03-04 18:12:49,085 - INFO - Scheduled search 38 of 10000
# 2025-03-04 18:12:49,086 - INFO - Scheduled search 39 of 10000
# 2025-03-04 18:12:49,087 - INFO - Scheduled search 40 of 10000
# 2025-03-04 18:12:49,089 - INFO - Scheduled search 41 of 10000
# 2025-03-04 18:12:49,091 - INFO - Scheduled search 42 of 10000
# 2025-03-04 18:12:49,092 - INFO - Scheduled search 43 of 10000
# 2025-03-04 18:12:49,093 - INFO - Scheduled search 44 of 10000
# 2025-03-04 18:12:49,094 - INFO - Scheduled search 45 of 10000
# 2025-03-04 18:12:49,095 - INFO - Scheduled search 46 of 10000
# 2025-03-04 18:12:49,095 - INFO - Scheduled search 47 of 10000
# 2025-03-04 18:12:49,096 - INFO - Scheduled search 48 of 10000
# 2025-03-04 18:12:49,098 - INFO - Scheduled search 49 of 10000
# 2025-03-04 18:12:49,101 - INFO - Scheduled search 50 of 10000
# 2025-03-04 18:12:49,101 - INFO - Scheduled search 51 of 10000
# 2025-03-04 18:12:49,102 - INFO - Scheduled search 52 of 10000
# 2025-03-04 18:12:49,103 - INFO - Scheduled search 53 of 10000
# 2025-03-04 18:12:49,104 - INFO - Scheduled search 54 of 10000
# 2025-03-04 18:12:49,104 - INFO - Scheduled search 55 of 10000
# 2025-03-04 18:12:49,104 - INFO - Scheduled search 56 of 10000
# 2025-03-04 18:12:49,105 - INFO - Scheduled search 57 of 10000
# 2025-03-04 18:12:49,105 - INFO - Scheduled search 58 of 10000
# 2025-03-04 18:12:49,106 - INFO - Scheduled search 59 of 10000
# 2025-03-04 18:12:49,107 - INFO - Scheduled search 60 of 10000
# 2025-03-04 18:12:49,107 - INFO - Scheduled search 61 of 10000
# 2025-03-04 18:12:49,108 - INFO - Scheduled search 62 of 10000
# 2025-03-04 18:12:49,109 - INFO - Scheduled search 63 of 10000
# 2025-03-04 18:12:49,110 - INFO - Scheduled search 64 of 10000
# 2025-03-04 18:12:49,110 - INFO - Scheduled search 65 of 10000
# 2025-03-04 18:12:49,110 - INFO - Scheduled search 66 of 10000
# 2025-03-04 18:12:49,111 - INFO - Scheduled search 67 of 10000
# 2025-03-04 18:12:49,112 - INFO - Scheduled search 68 of 10000
# 2025-03-04 18:12:49,118 - INFO - Scheduled search 69 of 10000
# 2025-03-04 18:12:49,186 - INFO - Scheduled search 70 of 10000
# 2025-03-04 18:12:49,188 - INFO - Scheduled search 71 of 10000
# 2025-03-04 18:12:49,197 - INFO - Scheduled search 72 of 10000
# 2025-03-04 18:12:49,203 - INFO - Scheduled search 73 of 10000
# 2025-03-04 18:12:49,212 - INFO - Scheduled search 74 of 10000
# 2025-03-04 18:12:49,222 - INFO - Scheduled search 75 of 10000
# 2025-03-04 18:12:49,225 - INFO - Scheduled search 76 of 10000
# 2025-03-04 18:12:49,225 - INFO - Scheduled search 77 of 10000
# 2025-03-04 18:12:49,226 - INFO - Scheduled search 78 of 10000
# 2025-03-04 18:12:49,227 - INFO - Scheduled search 79 of 10000
# 2025-03-04 18:12:49,227 - INFO - Scheduled search 80 of 10000
# 2025-03-04 18:12:49,229 - INFO - Scheduled search 81 of 10000
# 2025-03-04 18:12:49,230 - INFO - Scheduled search 82 of 10000
# 2025-03-04 18:12:49,231 - INFO - Scheduled search 83 of 10000
# 2025-03-04 18:12:49,232 - INFO - Scheduled search 84 of 10000
# 2025-03-04 18:12:49,233 - INFO - Scheduled search 85 of 10000
# 2025-03-04 18:12:49,234 - INFO - Scheduled search 86 of 10000
# 2025-03-04 18:12:49,235 - INFO - Scheduled search 87 of 10000
# 2025-03-04 18:12:49,237 - INFO - Scheduled search 88 of 10000
# 2025-03-04 18:12:49,238 - INFO - Scheduled search 89 of 10000
# 2025-03-04 18:12:49,240 - INFO - Scheduled search 90 of 10000
# 2025-03-04 18:12:49,241 - INFO - Scheduled search 91 of 10000
# 2025-03-04 18:12:49,242 - INFO - Scheduled search 92 of 10000
# 2025-03-04 18:12:49,243 - INFO - Scheduled search 93 of 10000
# 2025-03-04 18:12:49,243 - INFO - Scheduled search 94 of 10000
# 2025-03-04 18:12:49,244 - INFO - Scheduled search 95 of 10000
# 2025-03-04 18:12:49,245 - INFO - Scheduled search 96 of 10000
# 2025-03-04 18:12:49,247 - INFO - Scheduled search 97 of 10000
# 2025-03-04 18:12:49,247 - INFO - Scheduled search 98 of 10000
# 2025-03-04 18:12:49,248 - INFO - Scheduled search 99 of 10000
# 2025-03-04 18:12:49,250 - INFO - Scheduled search 100 of 10000
# 2025-03-04 18:12:49,251 - INFO - Scheduled search 101 of 10000
# 2025-03-04 18:12:49,252 - INFO - Scheduled search 102 of 10000
# 2025-03-04 18:12:49,253 - INFO - Scheduled search 103 of 10000
# 2025-03-04 18:12:49,254 - INFO - Scheduled search 104 of 10000
# 2025-03-04 18:12:49,255 - INFO - Scheduled search 105 of 10000
# 2025-03-04 18:12:49,255 - INFO - Scheduled search 106 of 10000
# 2025-03-04 18:12:49,256 - INFO - Scheduled search 107 of 10000
# 2025-03-04 18:12:49,257 - INFO - Scheduled search 108 of 10000
# 2025-03-04 18:12:49,259 - INFO - Scheduled search 109 of 10000
# 2025-03-04 18:12:49,260 - INFO - Scheduled search 110 of 10000
# 2025-03-04 18:12:49,260 - INFO - Scheduled search 111 of 10000
# 2025-03-04 18:12:49,261 - INFO - Scheduled search 112 of 10000
# 2025-03-04 18:12:49,262 - INFO - Scheduled search 113 of 10000
# 2025-03-04 18:12:49,263 - INFO - Scheduled search 114 of 10000
# 2025-03-04 18:12:49,264 - INFO - Scheduled search 115 of 10000
# 2025-03-04 18:12:49,265 - INFO - Scheduled search 116 of 10000
# 2025-03-04 18:12:49,265 - INFO - Scheduled search 117 of 10000
# 2025-03-04 18:12:49,266 - INFO - Scheduled search 118 of 10000
# 2025-03-04 18:12:49,266 - INFO - Scheduled search 119 of 10000
# 2025-03-04 18:12:49,267 - INFO - Scheduled search 120 of 10000
# 2025-03-04 18:12:49,268 - INFO - Scheduled search 121 of 10000
# 2025-03-04 18:12:49,268 - INFO - Scheduled search 122 of 10000
# 2025-03-04 18:12:49,269 - INFO - Scheduled search 123 of 10000
# 2025-03-04 18:12:49,270 - INFO - Scheduled search 124 of 10000
# 2025-03-04 18:12:49,270 - INFO - Scheduled search 125 of 10000
# 2025-03-04 18:12:49,271 - INFO - Scheduled search 126 of 10000
# 2025-03-04 18:12:49,271 - INFO - Scheduled search 127 of 10000
# 2025-03-04 18:12:49,272 - INFO - Scheduled search 128 of 10000
# 2025-03-04 18:12:49,273 - INFO - Scheduled search 129 of 10000
# 2025-03-04 18:12:49,274 - INFO - Scheduled search 130 of 10000
# 2025-03-04 18:12:49,274 - INFO - Scheduled search 131 of 10000
# 2025-03-04 18:12:49,275 - INFO - Scheduled search 132 of 10000
# 2025-03-04 18:12:49,276 - INFO - Scheduled search 133 of 10000
# 2025-03-04 18:12:49,277 - INFO - Scheduled search 134 of 10000
# 2025-03-04 18:12:49,278 - INFO - Scheduled search 135 of 10000
# 2025-03-04 18:12:49,278 - INFO - Scheduled search 136 of 10000
# 2025-03-04 18:12:49,279 - INFO - Scheduled search 137 of 10000
# 2025-03-04 18:12:49,279 - INFO - Scheduled search 138 of 10000
# 2025-03-04 18:12:49,280 - INFO - Scheduled search 139 of 10000
# 2025-03-04 18:12:49,281 - INFO - Scheduled search 140 of 10000
# 2025-03-04 18:12:49,282 - INFO - Scheduled search 141 of 10000
# 2025-03-04 18:12:49,282 - INFO - Scheduled search 142 of 10000
# 2025-03-04 18:12:49,283 - INFO - Scheduled search 143 of 10000
# 2025-03-04 18:12:49,283 - INFO - Scheduled search 144 of 10000
# 2025-03-04 18:12:49,284 - INFO - Scheduled search 145 of 10000
# 2025-03-04 18:12:49,284 - INFO - Scheduled search 146 of 10000
# 2025-03-04 18:12:49,285 - INFO - Scheduled search 147 of 10000
# 2025-03-04 18:12:49,285 - INFO - Scheduled search 148 of 10000
# 2025-03-04 18:12:49,286 - INFO - Scheduled search 149 of 10000
# 2025-03-04 18:12:49,286 - INFO - Scheduled search 150 of 10000
# 2025-03-04 18:12:49,287 - INFO - Scheduled search 151 of 10000
# 2025-03-04 18:12:49,288 - INFO - Scheduled search 152 of 10000
# 2025-03-04 18:12:49,288 - INFO - Scheduled search 153 of 10000
# 2025-03-04 18:12:49,289 - INFO - Scheduled search 154 of 10000
# 2025-03-04 18:12:49,291 - INFO - Scheduled search 155 of 10000
# 2025-03-04 18:12:49,294 - INFO - Scheduled search 156 of 10000
# 2025-03-04 18:12:49,296 - INFO - Scheduled search 157 of 10000
# 2025-03-04 18:12:49,296 - INFO - Scheduled search 158 of 10000
# 2025-03-04 18:12:49,297 - INFO - Scheduled search 159 of 10000
# 2025-03-04 18:12:49,297 - INFO - Scheduled search 160 of 10000
# 2025-03-04 18:12:49,298 - INFO - Scheduled search 161 of 10000
# 2025-03-04 18:12:49,298 - INFO - Scheduled search 162 of 10000
# 2025-03-04 18:12:49,299 - INFO - Scheduled search 163 of 10000
# 2025-03-04 18:12:49,299 - INFO - Scheduled search 164 of 10000
# 2025-03-04 18:12:49,300 - INFO - Scheduled search 165 of 10000
# 2025-03-04 18:12:49,301 - INFO - Scheduled search 166 of 10000
# 2025-03-04 18:12:49,304 - INFO - Scheduled search 167 of 10000
# 2025-03-04 18:12:49,305 - INFO - Scheduled search 168 of 10000
# 2025-03-04 18:12:49,305 - INFO - Scheduled search 169 of 10000
# 2025-03-04 18:12:49,308 - INFO - Scheduled search 170 of 10000
# 2025-03-04 18:12:49,309 - INFO - Scheduled search 171 of 10000
# 2025-03-04 18:12:49,310 - INFO - Scheduled search 172 of 10000
# 2025-03-04 18:12:49,311 - INFO - Scheduled search 173 of 10000
# 2025-03-04 18:12:49,311 - INFO - Scheduled search 174 of 10000
# 2025-03-04 18:12:49,312 - INFO - Scheduled search 175 of 10000
# 2025-03-04 18:12:49,312 - INFO - Scheduled search 176 of 10000
# 2025-03-04 18:12:49,312 - INFO - Scheduled search 177 of 10000
# 2025-03-04 18:12:49,313 - INFO - Scheduled search 178 of 10000
# 2025-03-04 18:12:49,314 - INFO - Scheduled search 179 of 10000
# 2025-03-04 18:12:49,315 - INFO - Scheduled search 180 of 10000
# 2025-03-04 18:12:49,315 - INFO - Scheduled search 181 of 10000
# 2025-03-04 18:12:49,316 - INFO - Scheduled search 182 of 10000
# 2025-03-04 18:12:49,317 - INFO - Scheduled search 183 of 10000
# 2025-03-04 18:12:49,318 - INFO - Scheduled search 184 of 10000
# 2025-03-04 18:12:49,319 - INFO - Scheduled search 185 of 10000
# 2025-03-04 18:12:49,320 - INFO - Scheduled search 186 of 10000
# 2025-03-04 18:12:49,320 - INFO - Scheduled search 187 of 10000
# 2025-03-04 18:12:49,320 - INFO - Scheduled search 188 of 10000
# 2025-03-04 18:12:49,321 - INFO - Scheduled search 189 of 10000
# 2025-03-04 18:12:49,321 - INFO - Scheduled search 190 of 10000
# 2025-03-04 18:12:49,323 - INFO - Scheduled search 191 of 10000
# 2025-03-04 18:12:49,323 - INFO - Scheduled search 192 of 10000
# 2025-03-04 18:12:49,323 - INFO - Scheduled search 193 of 10000
# 2025-03-04 18:12:49,324 - INFO - Scheduled search 194 of 10000
# 2025-03-04 18:12:49,402 - INFO - Scheduled search 195 of 10000
# 2025-03-04 18:12:49,432 - INFO - Scheduled search 196 of 10000
# 2025-03-04 18:12:49,457 - INFO - Scheduled search 197 of 10000
# 2025-03-04 18:12:49,485 - INFO - Scheduled search 198 of 10000
# 2025-03-04 18:12:49,488 - INFO - Scheduled search 199 of 10000
# 2025-03-04 18:12:49,490 - INFO - Scheduled search 200 of 10000
# 2025-03-04 18:12:49,491 - INFO - Scheduled search 201 of 10000
# 2025-03-04 18:12:49,491 - INFO - Scheduled search 202 of 10000
# 2025-03-04 18:12:49,492 - INFO - Scheduled search 203 of 10000
# 2025-03-04 18:12:49,492 - INFO - Scheduled search 204 of 10000
# 2025-03-04 18:12:49,493 - INFO - Scheduled search 205 of 10000
# 2025-03-04 18:12:49,494 - INFO - Scheduled search 206 of 10000
# 2025-03-04 18:12:49,494 - INFO - Scheduled search 207 of 10000
# 2025-03-04 18:12:49,496 - INFO - Scheduled search 208 of 10000
# 2025-03-04 18:12:49,497 - INFO - Scheduled search 209 of 10000
# 2025-03-04 18:12:49,497 - INFO - Scheduled search 210 of 10000
# 2025-03-04 18:12:49,498 - INFO - Scheduled search 211 of 10000
# 2025-03-04 18:12:49,498 - INFO - Scheduled search 212 of 10000
# 2025-03-04 18:12:49,499 - INFO - Scheduled search 213 of 10000
# 2025-03-04 18:12:49,499 - INFO - Scheduled search 214 of 10000
# 2025-03-04 18:12:49,500 - INFO - Scheduled search 215 of 10000
# 2025-03-04 18:12:49,500 - INFO - Scheduled search 216 of 10000
# 2025-03-04 18:12:49,501 - INFO - Scheduled search 217 of 10000
# 2025-03-04 18:12:49,502 - INFO - Scheduled search 218 of 10000
# 2025-03-04 18:12:49,503 - INFO - Scheduled search 219 of 10000
# 2025-03-04 18:12:49,503 - INFO - Scheduled search 220 of 10000
# 2025-03-04 18:12:49,504 - INFO - Scheduled search 221 of 10000
# 2025-03-04 18:12:49,504 - INFO - Scheduled search 222 of 10000
# 2025-03-04 18:12:49,506 - INFO - Scheduled search 223 of 10000
# 2025-03-04 18:12:49,507 - INFO - Scheduled search 224 of 10000
# 2025-03-04 18:12:49,508 - INFO - Scheduled search 225 of 10000
# 2025-03-04 18:12:49,508 - INFO - Scheduled search 226 of 10000
# 2025-03-04 18:12:49,508 - INFO - Scheduled search 227 of 10000
# 2025-03-04 18:12:49,509 - INFO - Scheduled search 228 of 10000
# 2025-03-04 18:12:49,509 - INFO - Scheduled search 229 of 10000
# 2025-03-04 18:12:49,509 - INFO - Scheduled search 230 of 10000
# 2025-03-04 18:12:49,510 - INFO - Scheduled search 231 of 10000
# 2025-03-04 18:12:49,510 - INFO - Scheduled search 232 of 10000
# 2025-03-04 18:12:49,510 - INFO - Scheduled search 233 of 10000
# 2025-03-04 18:12:49,512 - INFO - Scheduled search 234 of 10000
# 2025-03-04 18:12:49,512 - INFO - Scheduled search 235 of 10000
# 2025-03-04 18:12:49,513 - INFO - Scheduled search 236 of 10000
# 2025-03-04 18:12:49,514 - INFO - Scheduled search 237 of 10000
# 2025-03-04 18:12:49,514 - INFO - Scheduled search 238 of 10000
# 2025-03-04 18:12:49,515 - INFO - Scheduled search 239 of 10000
# 2025-03-04 18:12:49,515 - INFO - Scheduled search 240 of 10000
# 2025-03-04 18:12:49,516 - INFO - Scheduled search 241 of 10000
# 2025-03-04 18:12:49,516 - INFO - Scheduled search 242 of 10000
# 2025-03-04 18:12:49,517 - INFO - Scheduled search 243 of 10000
# 2025-03-04 18:12:49,517 - INFO - Scheduled search 244 of 10000
# 2025-03-04 18:12:49,518 - INFO - Scheduled search 245 of 10000
# 2025-03-04 18:12:49,518 - INFO - Scheduled search 246 of 10000
# 2025-03-04 18:12:49,519 - INFO - Scheduled search 247 of 10000
# 2025-03-04 18:12:49,519 - INFO - Scheduled search 248 of 10000
# 2025-03-04 18:12:49,519 - INFO - Scheduled search 249 of 10000
# 2025-03-04 18:12:49,520 - INFO - Scheduled search 250 of 10000
# 2025-03-04 18:12:49,521 - INFO - Scheduled search 251 of 10000
# 2025-03-04 18:12:49,521 - INFO - Scheduled search 252 of 10000
# 2025-03-04 18:12:49,522 - INFO - Scheduled search 253 of 10000
# 2025-03-04 18:12:49,535 - INFO - Scheduled search 254 of 10000
# 2025-03-04 18:12:49,579 - INFO - Scheduled search 255 of 10000
# 2025-03-04 18:12:49,591 - INFO - Scheduled search 256 of 10000
# 2025-03-04 18:12:49,612 - INFO - Scheduled search 257 of 10000
# 2025-03-04 18:12:49,614 - INFO - Scheduled search 258 of 10000
# 2025-03-04 18:12:49,615 - INFO - Scheduled search 259 of 10000
# 2025-03-04 18:12:49,618 - INFO - Scheduled search 260 of 10000
# 2025-03-04 18:12:49,618 - INFO - Scheduled search 261 of 10000
# 2025-03-04 18:12:49,620 - INFO - Scheduled search 262 of 10000
# 2025-03-04 18:12:50,342 - INFO - Scheduled search 263 of 10000
# 2025-03-04 18:12:50,458 - INFO - Scheduled search 264 of 10000
# 2025-03-04 18:12:50,467 - INFO - Scheduled search 265 of 10000
# 2025-03-04 18:12:50,487 - INFO - Scheduled search 266 of 10000
# 2025-03-04 18:12:50,502 - INFO - Scheduled search 267 of 10000
# 2025-03-04 18:12:50,535 - INFO - Scheduled search 268 of 10000
# 2025-03-04 18:12:50,648 - INFO - Scheduled search 269 of 10000
# 2025-03-04 18:12:50,698 - INFO - Scheduled search 270 of 10000
# 2025-03-04 18:12:50,765 - INFO - Scheduled search 271 of 10000
# 2025-03-04 18:12:50,766 - INFO - Scheduled search 272 of 10000
# 2025-03-04 18:12:50,769 - INFO - Scheduled search 273 of 10000
# 2025-03-04 18:12:50,779 - INFO - Scheduled search 274 of 10000
# 2025-03-04 18:12:50,855 - INFO - Scheduled search 275 of 10000
# 2025-03-04 18:12:50,890 - INFO - Scheduled search 276 of 10000
# 2025-03-04 18:12:50,965 - INFO - Scheduled search 277 of 10000
# 2025-03-04 18:12:51,036 - INFO - Scheduled search 278 of 10000
# 2025-03-04 18:12:51,075 - INFO - Scheduled search 279 of 10000
# 2025-03-04 18:12:51,111 - INFO - Scheduled search 280 of 10000
# 2025-03-04 18:12:51,186 - INFO - Scheduled search 281 of 10000
# 2025-03-04 18:12:51,220 - INFO - Scheduled search 282 of 10000
# 2025-03-04 18:12:51,222 - INFO - Scheduled search 283 of 10000
# 2025-03-04 18:12:51,225 - INFO - Scheduled search 284 of 10000
# 2025-03-04 18:12:51,227 - INFO - Scheduled search 285 of 10000
# 2025-03-04 18:12:51,228 - INFO - Scheduled search 286 of 10000
# 2025-03-04 18:12:51,242 - INFO - Scheduled search 287 of 10000
# 2025-03-04 18:12:51,244 - INFO - Scheduled search 288 of 10000
# 2025-03-04 18:12:51,250 - INFO - Scheduled search 289 of 10000
# 2025-03-04 18:12:51,271 - INFO - Fetching flights: ROM → PAR (2025-03-05 - 2025-03-09)
# 2025-03-04 18:12:51,271 - INFO - Scheduled search 290 of 10000
# 2025-03-04 18:12:51,349 - INFO - Scheduled search 291 of 10000
# 2025-03-04 18:12:51,353 - INFO - Scheduled search 292 of 10000
# 2025-03-04 18:12:51,354 - INFO - Scheduled search 293 of 10000
# 2025-03-04 18:12:51,355 - INFO - Scheduled search 294 of 10000
# 2025-03-04 18:12:51,355 - INFO - Scheduled search 295 of 10000
# 2025-03-04 18:12:51,358 - INFO - Scheduled search 296 of 10000
# 2025-03-04 18:12:51,360 - INFO - Scheduled search 297 of 10000
# 2025-03-04 18:12:51,361 - INFO - Scheduled search 298 of 10000
# 2025-03-04 18:12:51,361 - INFO - Scheduled search 299 of 10000
# 2025-03-04 18:12:51,363 - INFO - Scheduled search 300 of 10000
# 2025-03-04 18:12:52,071 - INFO - Fetching flights: ROM → PAR (2025-03-07 - 2025-03-10)
# 2025-03-04 18:12:52,082 - INFO - Fetching flights: ROM → PAR (2025-03-06 - 2025-03-09)
# 2025-03-04 18:12:52,083 - INFO - Fetching flights: ROM → PAR (2025-03-07 - 2025-03-11)
# 2025-03-04 18:12:52,084 - INFO - Fetching flights: ROM → PAR (2025-03-05 - 2025-03-06)
# 2025-03-04 18:12:52,100 - INFO - Fetching flights: ROM → PAR (2025-03-05 - 2025-03-10)
# 2025-03-04 18:12:52,112 - INFO - Fetching flights: ROM → PAR (2025-03-07 - 2025-03-08)
# 2025-03-04 18:12:52,112 - INFO - Fetching flights: ROM → PAR (2025-03-05 - 2025-03-07)
# 2025-03-04 18:12:52,113 - INFO - Fetching flights: ROM → PAR (2025-03-07 - 2025-03-09)
# 2025-03-04 18:12:52,113 - INFO - Fetching flights: ROM → PAR (2025-03-06 - 2025-03-08)
# 2025-03-04 18:12:52,115 - INFO - Fetching flights: ROM → PAR (2025-03-06 - 2025-03-07)
# 2025-03-04 18:12:52,118 - INFO - Fetching flights: ROM → PAR (2025-03-06 - 2025-03-10)
# 2025-03-04 18:12:52,127 - INFO - Fetching flights: ROM → PAR (2025-03-07 - 2025-03-12)
# 2025-03-04 18:12:52,137 - INFO - Fetching flights: ROM → PAR (2025-03-06 - 2025-03-11)
# 2025-03-04 18:12:52,116 - INFO - Fetching flights: ROM → PAR (2025-03-05 - 2025-03-08)
# 2025-03-04 18:12:58,231 - WARNING - No 'View more flights' button found for ROM → PAR
# 2025-03-04 18:12:58,342 - WARNING - No 'View more flights' button found for ROM → PAR
# 2025-03-04 18:12:58,596 - WARNING - No 'View more flights' button found for ROM → PAR
# 2025-03-04 18:13:01,589 - WARNING - No 'View more flights' button found for ROM → PAR
# 2025-03-04 18:13:01,668 - WARNING - No 'View more flights' button found for ROM → PAR
# 2025-03-04 18:13:02,017 - WARNING - No 'View more flights' button found for ROM → PAR
# 2025-03-04 18:13:02,051 - WARNING - No 'View more flights' button found for ROM → PAR
# 2025-03-04 18:13:02,083 - WARNING - No 'View more flights' button found for ROM → PAR
# 2025-03-04 18:13:02,153 - WARNING - No 'View more flights' button found for ROM → PAR
# 2025-03-04 18:13:02,857 - WARNING - No 'View more flights' button found for ROM → PAR
# 2025-03-04 18:13:03,017 - WARNING - No 'View more flights' button found for ROM → PAR
# 2025-03-04 18:13:03,429 - WARNING - No 'View more flights' button found for ROM → PAR
# 2025-03-04 18:13:03,718 - WARNING - No 'View more flights' button found for ROM → PAR
# 2025-03-04 18:13:03,720 - WARNING - No 'View more flights' button found for ROM → PAR
# 2025-03-04 18:13:03,815 - WARNING - No 'View more flights' button found for ROM → PAR
# 2025-03-04 18:13:09,416 - INFO - Completed: ROM → PAR (TTT: 2, LOS: 4), Found 0 flights.
# 2025-03-04 18:13:09,427 - INFO - Completed: ROM → PAR (TTT: 3, LOS: 1), Found 0 flights.
# 2025-03-04 18:13:09,656 - INFO - Completed: ROM → PAR (TTT: 3, LOS: 2), Found 0 flights.
# 2025-03-04 18:13:10,348 - INFO - Fetching flights: ROM → PAR (2025-03-08 - 2025-03-10)
# 2025-03-04 18:13:10,351 - INFO - Fetching flights: ROM → PAR (2025-03-08 - 2025-03-09)
# 2025-03-04 18:13:10,541 - INFO - Fetching flights: ROM → PAR (2025-03-08 - 2025-03-11)
# 2025-03-04 18:13:12,347 - INFO - Completed: ROM → PAR (TTT: 2, LOS: 1), Found 0 flights.
# 2025-03-04 18:13:12,637 - INFO - Completed: ROM → PAR (TTT: 1, LOS: 2), Found 0 flights.
# 2025-03-04 18:13:12,771 - INFO - Completed: ROM → PAR (TTT: 2, LOS: 3), Found 0 flights.
# 2025-03-04 18:13:12,804 - INFO - Completed: ROM → PAR (TTT: 3, LOS: 4), Found 0 flights.
# 2025-03-04 18:13:12,805 - INFO - Completed: ROM → PAR (TTT: 1, LOS: 4), Found 0 flights.
# 2025-03-04 18:13:12,848 - INFO - Completed: ROM → PAR (TTT: 1, LOS: 3), Found 0 flights.
